# %% [markdown]
# <style>
# #rubric-table {
#     border-collapse: collapse;
#     width: 100%;
#     font-family: Arial, sans-serif;
#     margin: 20px 0;
# }
# #rubric-table th {
#     background-color: #f8f9fa;
#     border: 1px solid #dee2e6;
#     padding: 12px 8px;
#     text-align: left;
#     font-weight: bold;
#     font-size: 14px;
#     vertical-align: top;
# }
# #rubric-table td {
#     border: 1px solid #dee2e6;
#     padding: 12px 8px;
#     text-align: left;
#     font-size: 13px;
#     vertical-align: top;
#     line-height: 1.4;
# }
# #rubric-table th:nth-child(1),
# #rubric-table td:nth-child(1) {
#     width: 25%;
# }
# #rubric-table th:nth-child(2),
# #rubric-table td:nth-child(2) {
#     width: 25%;
# }
# #rubric-table th:nth-child(3),
# #rubric-table td:nth-child(3) {
#     width: 25%;
# }
# #rubric-table th:nth-child(4),
# #rubric-table td:nth-child(4) {
#     width: 25%;
# }
# </style>
# <table id="rubric-table">
# <thead>
#     <tr>
#         <th>3 points (Great)</th>
#         <th>2 points (Good)</th>
#         <th>1 points (Satisfactory)</th>
#         <th>0 points (Missing)</th>
#     </tr>
# </thead>
# <tbody>
#     <tr>
#         <td>Complete, well-organized, and carefully reasoned. All sections are thorough, accurate, and clearly connect statistical results to the research question. Jamovi output is complete and correct.</td>
#         <td>All sections included and mostly accurate. Minor calculation, APA, or interpretation errors present but meaning is clear. Jamovi output is mostly complete and correct, with minor omissions or inaccuracies.</td>
#         <td>Most sections present but with gaps in clarity, accuracy, or organization. Calculation, APA, and interpretation inconsistencies evident. Jamovi output included but incomplete or partially incorrect.</td>
#         <td>Lab report or Jamovi output missing, or submission too incomplete to evaluate.</td>
#     </tr>
# </tbody>
# </table>
