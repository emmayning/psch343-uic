# %% [markdown]
# # Statistical Methods in Behavioral Science

# %%
# %config InlineBackend.figure_format = 'retina' # High-res plots for Jupyter
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Summary & Course Logistics

# %% [markdown]
# * **Term, CRN and Number of credits:** Fall 2025, 12245 (PSCH 343), 4 credits
# * **Lecture Meeting Time & Location:** 2 - 3:15 pm, Tuesdays & Thursdays @ Lincoln Hall Room 307
# * **Discussion Meeting Time & Location:** 1 - 1:50 pm, Fridays @ Behavioral Sciences Building Room 2057
# * **Instructor:** Emma Ning, M.A. (yning7@uic.edu)
# * **Office Hours & Location:** Fridays 2 - 3 pm @ BSB 1015

# %% [markdown]
# ## 2. Course Overview

# %% [markdown]
# Welcome to PSCH 343, Statistical Methods in Behavioral Science! The goal of this class is to equip you with the **essential analytical mindset and tools to interpret and evaluate quantitative research findings**. Building on the knowledge of experimental design (PSCH 242), research process, and research writing, we will explore how statistical methods inform psychological research and data-driven decision-making.
#
# Topics covered include: 1). descriptive statistics (mean, standard deviation); 2). sampling, and 3). inferential statistics (t-tests, ANOVA, correlation). These concepts form the foundation of psychological research methods and data science. **All course material will be motivated by practical applications of these tools in the context of research in both academia and industry**.
#
# After this class, you should be ready to contribute to a research team from day one. You will be able to summarize data, run basic statistical tests, and present findings clearly. Whether informing research decisions or setting the stage for more advanced analyses, you will have the skills to translate raw data into meaningful insights that drive the next steps in a study.

# %% [markdown]
# ## 3. Learning Objectives

# %% [markdown]
# * **Summarize and visualize** data using descriptive statistics and graphs, and explain observed patterns in clear, non-technical language.
# * **Translate** hypotheses into testable statistical analyses.
# * **Select and justify** appropriate statistical tests for a given hypothesis and study design.
# * **Execute** statistical analyses from start to finish — carrying out the chosen test accurately by hand and with open-source software, and articulating the reasoning for each step.
# * **Interpret results and communicate findings** effectively for different audiences and decision-making contexts.

# %% [markdown]
# ## 4. Weekly Schedule

# %% [markdown]
# | Week |    Date    |             Topic             | Reading | Assignment |
# | :--: | :--------: | :---------------------------: | :-----: | :--------: |
# | **1**  | 8/26 (Tu)  | Course Welcome  |         |  Read syllabus |
# |       | 8/28 (Th)  |  Understanding & Visualizing Data  |         |            |
# |       | 8/29 (Fr)  |  **Lab 1**: |         | Lab report 1 |
# | **2**  | 9/2  (Tu)  |  Central Tendency, Modality, Skewness  |         |            |
# |       | 9/4  (Th)  |  Measures of Variability  |         |            |
# |       | 9/5  (Fr)  | **Lab 2**:   |         | Lab report 2; Homework 1 Due Sun 9/7 @ 11:59 pm |
# | **3**  | 9/9  (Tu)  |  Z-Scores & Probability |         |            |
# |       | 9/11 (Th)  |  Sampling Distributions  |         |            |
# |       | 9/12 (Fr)  |  **Lab 3**: |         | Lab report 3;  Homework 2 Due Sun 9/14 @ 11:59 pm|
# | **4**  | 9/16 (Tu)  |  Sampling & Inference, Introduction to Hypothesis Testing |         |            |
# |       | 9/18 (Th)  | Hypothesis Testing, Part 2 |         |            |
# |       | 9/19 (Fr)  |  **Lab**:  |         | Exam Prep, No lab report |
# | **5**  | 9/23 (Tu)  |  Exam 1 Review/Flex Day |         |            |
# |       | 9/25 (Th)  |  Exam 1 |         |            |
# |       | 9/26 (Fr)  |   **No Lab** |         |            |
# | **6**  | 9/30 (Tu)  | One-Sample t-test |         |            |
# |       | 10/2 (Th)  | Indepedent Samples t-test, Part 1  |         |            |
# |       | 10/3 (Fr)  |  **Lab 4**:  |         | Lab report 4; Homework 3 Due Sun 10/5 @11:59 pm|
# | **7**  | 10/7 (Tu)  |  Indepedent Samples t-test, Part 2  |         |            |
# |       | 10/9 (Th)  | Paired Samples t-test, Part 1  |         |            |
# |       | 10/10 (Fr) | **Lab 5**: |         | Lab report 5 |
# | **8**  | 10/14 (Tu) |  Paired Samples t-test, Part 2 |         |            |
# |       | 10/16 (Th) |  One-way ANOVA, Part 1 |         |            |
# |       | 10/17 (Fr) |  **Lab 6**:  |         | Lab report 6; Homework 4 Due Sun 10/19 @11:59 pm|
# | **9**  | 10/21 (Tu) | One-way ANOVA, Part 2 |    |     |
# |       | 10/23 (Th) | Factorial ANOVA, Part 1 |         |            |
# |       | 10/24 (Fr) | **Lab 7** |         |  Lab report 7 |
# | **10** | 10/28 (Tu) |  Factorial ANOVA, Part 2  |         |            |
# |       | 10/30 (Th) |  ANOVA Practice Day  |         |            |
# |       | 10/31 (Fr) | **No Lab**:  |         | Exam Prep, No lab report; Homework 5 Due Sun 11/2 @11:59 pm |
# | **11** | 11/4  (Tu) |   Exam 2 Review/Flex Day  |         |            |
# |       | 11/6  (Th) |  Exam 2  |         |            |
# |       | 11/7  (Fr) |  **No Lab**  |         |            |
# | **12** | 11/11 (Tu) |  Chi-squared Test   |         |            |
# |       | 11/13 (Th) |  Correlation |         |            |
# |       | 11/14 (Fr) |  **Lab 8**:  |         |  Lab report 8; Homework 6 Due Sun 11/16 @11:59 pm|
# | **13** | 11/18 (Tu) |  Hands-On Data Analysis, Part 1   |         |            |
# |       | 11/20 (Th) |  Hands-On Data Analysis, Part 2  |         |            |
# |       | 11/21 (Fr) |  **Lab 9**:  |         | Lab report 9 |
# | **14** | 11/25 (Tu) |  Guest Lecture  |         |            |
# |       | 11/27 (Th) | No Class (Thanksgiving)       |         |            |
# |       | 11/28 (Fr) | No Class (Thanksgiving)       |         |            |
# | **15** | 12/2  (Tu) | Communicating Statistics |         |            |
# |       | 12/4  (Th) |  Exam 3 Review  |         |            |
# |       | 12/5  (Fr) |  **No Lab**  |         |            |

# %% [markdown]
# ## 5. Grading Policy

# %% [markdown]
# | Total Points | Letter Grade |
# | :-----------: |:-------------: |
# | 90 - 100 | A |
# | 80 - 89 | B |
# | 70 - 79 | C |
# | 60 - 69 | D |
# | $\leq$ 59 | F |

# %% [markdown]
# ### Here's the overall grading breakdown:

# %%
# Data
labels = ['Lectures (in-class activities)', 'Lab Reports', 'Homeworks', 'Exams']
sizes = [15, 20, 20, 45]  # Number of each category
colors = ['#0461cf', '#0073e6', '#8babf1', '#b3c7f7']  # Accessible colors

# Create pie chart
plt.figure(figsize=(2,2), dpi=250)
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=colors,
       textprops={'fontsize':4})
plt.show()

# %% [markdown]
# Your grade, as shown in the pie chart, is based on two broad categories: Attendance and Your Work. These items in the pie chart fall into one of these categories, which together determine your final grade.
#
# ### 1. Attendance
# - **Lectures**: 24 total (excluding exams and review sessions).
#   - Each lecture includes an in-class activity (ICA), which counts toward your attendance grade.
#   - You may miss up to **6 lectures** (i.e., 6 in-class activities) **without penalty**.
# - **Labs**: 9 total.
#   - Attendance is **mandatory**.
#   - While not every lab requires a report, lab content is cumulative and crucial for homework and exams.
#
# ### 2. Your Work
# - **Lab Reports**: 9 total (*lowest 1 dropped*). Lab attendance is mandatory, and lab reports are designed to be completed in small groups during lab time and are due on the day of that discussion section.
# - **Homeworks**: 6 total (*lowest 1 dropped*). Homework due dates are specified in the course content table.
# - **Exams**: 3 total (*no drops*, the first two are non-cumulative, the last exam is cumulative).
# - **Late Submissions for lab report and homeworks**:
#   - **24-hour grace period**: No penalty.
#   - After the grace period: **One letter grade deducted per day late**.
# - **Extra Credit (surveys)**: Throughout the course, you will have the opportunity to complete a few extra credit surveys, which will help us generate data that we will use in class. There will also be extra credit short surveys for me to get feedback on the course. Every completed extra credit survey will count towards one bonus point on your lowest exam score.

# %% [markdown]
# ## 6. Course materials

# %% [markdown]
# **What materials do I need?**
# In this course, you will need to have access to the following:
#
# * Laptop with a stable internet connection
# * Free, online [textbook](https://umsystem.pressbooks.pub/isps/) (optional, but highly recommended)
# * A simple calculator (for exams)
# * Jamovi (free software, see below)
# * Smartphone or Tablet (with a camera that can scan QR codes)

# %% [markdown]
# **What is the purpose of the textbook?**
# The lectures, labs, and homework are designed to stand on their own. The textbook is an optional supplement you can use to reinforce your learning, especially if a concept isn’t clicking. In addition to office hours and online resources, the book offers alternative explanations that may help things make more sense. While you can succeed in this class without it, some students find it a useful reference.

# %% [markdown]
# **Jamovi?**
# Jamovi is a free and open-source computer program for data analysis. **You will need to have access to a laptop for this course, particularly during the Friday lab sections.** We will have a limited number of backup laptops available for students who need them. Please visit the Jamovi [download site](https://www.jamovi.org/download.html) to download this software before your first lab session.
# Using statistical software is a valuable skill that can make you more competitive in the job market. While Excel is a powerful tool for many tasks, some analyses are better done with dedicated statistical software. Learning to use free, open-source tools like Jamovi will prepare you for those situations, and this semester will give you the skills to do it confidently.
